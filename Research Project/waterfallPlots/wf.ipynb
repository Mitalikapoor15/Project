# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
# # Load the data from the file (assumes it's space or tab delimited)
# data1 = np.loadtxt("C:\\Users\\Mitali\\OneDrive\\Desktop\\Research Project\\portData\\port1.dat")
# data2 = np.loadtxt("C:\\Users\\Mitali\\OneDrive\\Desktop\\Research Project\\portData\\port2.dat")
# data3 = np.loadtxt("C:\\Users\\Mitali\\OneDrive\\Desktop\\Research Project\\portData\\port3.dat")



# # Transpose the data
# trans1 = data1.T
# trans2 = data2.T
# trans3 = data3.T


# # Save transposed data to a new file
# np.savetxt("port1_transposed.dat", trans1, fmt="%.6f")
# np.savetxt("port2_transposed.dat", trans2, fmt="%.6f")
# np.savetxt("port3_transposed.dat", trans3, fmt="%.6f")

# %%
# List of input and output file paths
input_files = [
    "C:\\Users\\Mitali\\OneDrive\\Desktop\\Research Project\\portData\\port1.dat",
    "C:\\Users\\Mitali\\OneDrive\\Desktop\\Research Project\\portData\\port2.dat",
    "C:\\Users\\Mitali\\OneDrive\\Desktop\\Research Project\\portData\\port3.dat"
]

output_files = [
    "port1_transposed.dat",
    "port2_transposed.dat",
    "port3_transposed.dat"
]

# Loop over files: load, transpose, and save
for in_file, out_file in zip(input_files, output_files):
    data = np.loadtxt(in_file)
    transposed = data.T
    np.savetxt(out_file, transposed, fmt="%.6f")

# %%
# List of transposed .dat files
input_files = [
    "port1_transposed.dat",
    "port2_transposed.dat",
    "port3_transposed.dat"
]

# Waterfall plot parameters
num_rows_to_plot = 60
offset = 1
colormap_name = 'cool'

# Load and plot each file
for idx, filename in enumerate(input_files, start=1):
    # Load data
    data = np.loadtxt(filename)
    transposed = data.T

    # Create colormap
    cmap = cm.get_cmap(colormap_name, num_rows_to_plot)

    # Create waterfall plot
    plt.figure(figsize=(10, 6))
    for i in range(num_rows_to_plot):
        color = cmap(i)
        plt.plot(transposed[i] + i * offset, color=color)
        # Optional label: uncomment to enable legends
        # plt.plot(transposed[i] + i * offset, color=color, label=f"Ez {i}")

    plt.title(f"Waterfall Plot for PORT {idx}")
    plt.xlabel("Time Steps")
    plt.ylabel("Ez")
    # plt.legend()  # Optional if labels are added
    plt.grid(True)
    plt.tight_layout()

    # Save figure
    plt.savefig(f"wf_port{idx}.png", dpi=300, bbox_inches='tight')
    plt.show()
# Out:
# C:\Users\Mitali\AppData\Local\Temp\ipykernel_28136\1997228963.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap(colormap_name, num_rows_to_plot)

# %%
# Plot the first row after transposing (i.e., originally the first column)
plt.plot(trans1[60])
plt.plot(trans1[30])
plt.title("Port 1")
plt.xlabel("Time Steps")
plt.ylabel("Ez Values")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[94], line 2
#       1 # Plot the first row after transposing (i.e., originally the first column)
# ----> 2 plt.plot(trans1[60])
#       3 plt.plot(trans1[30])
#       4 plt.title("Port 1")
#
# NameError: name 'trans1' is not defined

# %%
# Choose how many rows to plot (adjust as needed)
num_rows_to_plot = 40
offset = 0.4  # vertical shift between plots

# Choose a colormap
cmap = cm.get_cmap('cool', num_rows_to_plot)  # 'viridis', 'cool', 'inferno', etc.

# Create waterfall plot
plt.figure(figsize=(10, 6))
for i in range(num_rows_to_plot):
    color = cmap(i)  # Get a color from the colormap
    plt.plot(transposed[i] + i * offset, color=color)
    #, label=f"Ez {i}"

plt.title("Waterfall Plot for PORT 1")
plt.xlabel("Time Steps")
plt.ylabel("Ez")
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.savefig("wf_port1.png", dpi=300, bbox_inches='tight')  # or .pdf, .svg, .jpg
plt.show()
# Out:
# C:\Users\Mitali\AppData\Local\Temp\ipykernel_28136\1336155905.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('cool', num_rows_to_plot)  # 'viridis', 'cool', 'inferno', etc.
# C:\Users\Mitali\AppData\Local\Temp\ipykernel_28136\1336155905.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
